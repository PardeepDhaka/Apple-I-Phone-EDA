# %%
#Load the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import wordcloud

# %%
df=pd.read_csv('D:\Coach X\Python\Apple_Iphone\\apple_products.csv')

# %%
df.head()
# Out:
#                                Product Name  \
# 0         APPLE iPhone 8 Plus (Gold, 64 GB)
# 1  APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2      APPLE iPhone 8 Plus (Silver, 256 GB)
# 3           APPLE iPhone 8 (Silver, 256 GB)
# 4             APPLE iPhone 8 (Gold, 256 GB)
#
#                                          Product URL  Brand  Sale Price  \
# 0  https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3  https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# 4  https://www.flipkart.com/apple-iphone-8-gold-2...  Apple       77000
#
#      Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 0  49900                    0               3431                356
# 1  84900                    0               3431                356
# ...

# %%
df.tail()
# Out:
#                        Product Name  \
# 57   APPLE iPhone SE (Black, 64 GB)
# 58  APPLE iPhone 11 (Purple, 64 GB)
# 59   APPLE iPhone 11 (White, 64 GB)
# 60   APPLE iPhone 11 (Black, 64 GB)
# 61     APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 57  https://www.flipkart.com/apple-iphone-se-black...  Apple       29999
# 58  https://www.flipkart.com/apple-iphone-11-purpl...  Apple       46999
# 59  https://www.flipkart.com/apple-iphone-11-white...  Apple       46999
# 60  https://www.flipkart.com/apple-iphone-11-black...  Apple       46999
# 61  https://www.flipkart.com/apple-iphone-11-red-6...  Apple       46999
#
#       Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 57  39900                   24              95909               8161
# 58  54900                   14              43470               3331
# 59  54900                   14              43470               3331
# ...

# %%
df.shape
# Out:
# (62, 11)

# %%
df.columns
# Out:
# Index(['Product Name', 'Product URL', 'Brand', 'Sale Price', 'Mrp',
#        'Discount Percentage', 'Number Of Ratings', 'Number Of Reviews', 'Upc',
#        'Rating', 'Ram'],
#       dtype='object')

# %%
#Basic information

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Product Name         62 non-null     object
#  1   Product URL          62 non-null     object
#  2   Brand                62 non-null     object
#  3   Sale Price           62 non-null     int64
#  4   Mrp                  62 non-null     int64
#  5   Discount Percentage  62 non-null     int64
#  6   Number Of Ratings    62 non-null     int64
#  7   Number Of Reviews    62 non-null     int64
#  8   Upc                  62 non-null     object
#  9   Star Rating          62 non-null     float64
#  10  Ram                  62 non-null     object
# dtypes: float64(1), int64(5), object(5)
# memory usage: 5.5+ KB

# %%
#Describe the data

df.describe()
# Out:
#           Sale Price            Mrp  Discount Percentage  Number Of Ratings  \
# count      62.000000      62.000000            62.000000          62.000000
# mean    80073.887097   88058.064516             9.951613       22420.403226
# std     34310.446132   34728.825597             7.608079       33768.589550
# min     29999.000000   39900.000000             0.000000         542.000000
# 25%     49900.000000   54900.000000             6.000000         740.000000
# 50%     75900.000000   79900.000000            10.000000        2101.000000
# 75%    117100.000000  120950.000000            14.000000       43470.000000
# max    140900.000000  149900.000000            29.000000       95909.000000
#
#        Number Of Reviews     Rating
# count          62.000000  62.000000
# mean         1861.677419   4.575806
# std          2855.883830   0.059190
# min            42.000000   4.500000
# 25%            64.000000   4.500000
# 50%           180.000000   4.600000
# ...

# %%
df.isnull().sum()
# Out:
# Product Name           0
# Product URL            0
# Brand                  0
# Sale Price             0
# Mrp                    0
# Discount Percentage    0
# Number Of Ratings      0
# Number Of Reviews      0
# Upc                    0
# Rating                 0
# Ram                    0
# dtype: int64

# %%
#Find the duplicates

df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True,ignore_index=True)

# %%
df.head()
# Out:
#                                Product Name  \
# 0         APPLE iPhone 8 Plus (Gold, 64 GB)
# 1  APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2      APPLE iPhone 8 Plus (Silver, 256 GB)
# 3           APPLE iPhone 8 (Silver, 256 GB)
# 4             APPLE iPhone 8 (Gold, 256 GB)
#
#                                          Product URL  Brand  Sale Price  \
# 0  https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3  https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# 4  https://www.flipkart.com/apple-iphone-8-gold-2...  Apple       77000
#
#      Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 0  49900                    0               3431                356
# 1  84900                    0               3431                356
# ...

# %%
df.tail()
# Out:
#                        Product Name  \
# 57   APPLE iPhone SE (Black, 64 GB)
# 58  APPLE iPhone 11 (Purple, 64 GB)
# 59   APPLE iPhone 11 (White, 64 GB)
# 60   APPLE iPhone 11 (Black, 64 GB)
# 61     APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 57  https://www.flipkart.com/apple-iphone-se-black...  Apple       29999
# 58  https://www.flipkart.com/apple-iphone-11-purpl...  Apple       46999
# 59  https://www.flipkart.com/apple-iphone-11-white...  Apple       46999
# 60  https://www.flipkart.com/apple-iphone-11-black...  Apple       46999
# 61  https://www.flipkart.com/apple-iphone-11-red-6...  Apple       46999
#
#       Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 57  39900                   24              95909               8161
# 58  54900                   14              43470               3331
# 59  54900                   14              43470               3331
# ...

# %%
df.shape
# Out:
# (62, 11)

# %%
#unique values

df.nunique()
# Out:
# Product Name           62
# Product URL            62
# Brand                   1
# Sale Price             24
# Mrp                    22
# Discount Percentage    16
# Number Of Ratings      19
# Number Of Reviews      18
# Upc                    62
# Rating                  3
# Ram                     4
# dtype: int64

# %%
df["Product Name"].value_counts()
# Out:
# APPLE iPhone 8 Plus (Gold, 64 GB)                 1
# APPLE iPhone 12 Pro (Pacific Blue, 128 GB)        1
# APPLE iPhone 12 Mini (Black, 128 GB)              1
# APPLE iPhone 12 Mini (Blue, 128 GB)               1
# APPLE iPhone 12 (Black, 128 GB)                   1
#                                                  ..
# APPLE iPhone 12 Pro Max (Pacific Blue, 256 GB)    1
# APPLE iPhone 12 Mini (White, 128 GB)              1
# APPLE iPhone 12 Pro (Graphite, 256 GB)            1
# APPLE iPhone 12 Mini (White, 64 GB)               1
# APPLE iPhone 11 (Red, 64 GB)                      1
# Name: Product Name, Length: 62, dtype: int64

# %%
df.groupby(['Product Name', 'Brand']).mean()
# Out:
#                                                           Sale Price      Mrp  \
# Product Name                                       Brand
# APPLE iPhone 11 (Black, 128 GB)                    Apple     54999.0  59900.0
# APPLE iPhone 11 (Black, 64 GB)                     Apple     46999.0  54900.0
# APPLE iPhone 11 (Purple, 64 GB)                    Apple     46999.0  54900.0
# APPLE iPhone 11 (Red, 128 GB)                      Apple     54999.0  59900.0
# APPLE iPhone 11 (Red, 64 GB)                       Apple     46999.0  54900.0
# ...                                                              ...      ...
# Apple iPhone XR ((PRODUCT)RED, 128 GB) (Include... Apple     41999.0  52900.0
# Apple iPhone XR (Black, 128 GB) (Includes EarPo... Apple     41999.0  52900.0
# Apple iPhone XR (Black, 64 GB) (Includes EarPod... Apple     39999.0  47900.0
# Apple iPhone XR (Coral, 128 GB) (Includes EarPo... Apple     41999.0  52900.0
# ...

# %%
df.count()      # Used to count the number of rows
# Out:
# Product Name           62
# Product URL            62
# Brand                  62
# Sale Price             62
# Mrp                    62
# Discount Percentage    62
# Number Of Ratings      62
# Number Of Reviews      62
# Upc                    62
# Rating                 62
# Ram                    62
# dtype: int64

# %%
df.rename(columns={'Star Rating': 'Rating'}, inplace=True)

# %%
#Replace null values

df.replace(np.nan,'0',inplace = True)

#Check the changes now
df.isnull().sum()
# Out:
# Product Name           0
# Product URL            0
# Brand                  0
# Sale Price             0
# Mrp                    0
# Discount Percentage    0
# Number Of Ratings      0
# Number Of Reviews      0
# Upc                    0
# Star Rating            0
# Ram                    0
# dtype: int64

# %%
#Datatypes

df.dtypes
# Out:
# Product Name            object
# Product URL             object
# Brand                   object
# Sale Price               int64
# Mrp                      int64
# Discount Percentage      int64
# Number Of Ratings        int64
# Number Of Reviews        int64
# Upc                     object
# Star Rating            float64
# Ram                     object
# dtype: object

# %%
#Filter data

df[df['Star Rating']==4.6].head(10)
# Out:
#                                          Product Name  \
# 0                   APPLE iPhone 8 Plus (Gold, 64 GB)
# 1            APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2                APPLE iPhone 8 Plus (Silver, 256 GB)
# 5                 APPLE iPhone 8 Plus (Silver, 64 GB)
# 6             APPLE iPhone 8 Plus (Space Grey, 64 GB)
# 8                 APPLE iPhone XS Max (Silver, 64 GB)
# 9   Apple iPhone XR ((PRODUCT)RED, 128 GB) (Includ...
# 10  Apple iPhone XR (Black, 64 GB) (Includes EarPo...
# 11  Apple iPhone XR (Coral, 128 GB) (Includes EarP...
# 12  Apple iPhone XR (Black, 128 GB) (Includes EarP...
#
#                                           Product URL  Brand  Sale Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 5   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       49900
# ...

# %%
#Correlation 

df.corr()
# Out:
#                      Sale Price       Mrp  Discount Percentage  \
# Sale Price             1.000000  0.985108            -0.569603
# Mrp                    0.985108  1.000000            -0.434340
# Discount Percentage   -0.569603 -0.434340             1.000000
# Number Of Ratings     -0.701526 -0.670093             0.684827
# Number Of Reviews     -0.696029 -0.664651             0.685877
# Rating                 0.303772  0.264509            -0.348479
#
#                      Number Of Ratings  Number Of Reviews    Rating
# Sale Price                   -0.701526          -0.696029  0.303772
# Mrp                          -0.670093          -0.664651  0.264509
# Discount Percentage           0.684827           0.685877 -0.348479
# Number Of Ratings             1.000000           0.999084 -0.224977
# Number Of Reviews             0.999084           1.000000 -0.227863
# Rating                       -0.224977          -0.227863  1.000000

# %%
#Plot the unique values

sns.countplot(df['Sale Price'])

#sns.countplot(data=df, x='Sale Price')
plt.xticks(rotation=85)  # Adjust the rotation angle here
plt.show()
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Correlation plot

sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=df['Rating'])
# Out:
# <AxesSubplot:xlabel='Rating'>

# %%
# Out:
# ...
#
# ...

# %%
#Wordclouds to find highlighted Brand
plt.figure(figsize=(10,8))
Brand = " ".join(df['Product Name'].tolist())
wordcloud = WordCloud(width=1000,height=500).generate(Brand)
plt.imshow(wordcloud)
plt.title("Wordcloud for Brand")
plt.show()
